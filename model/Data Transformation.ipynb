# %%
import pandas as pd
from pathlib import Path

# %%
#Read csv
#malicious_csv = pd.read_csv('../data/malicious_only_cpy.csv')
#benign_csv = pd.read_csv('../data/benign_out_testing.csv')
all_csv = pd.read_csv('../test_data/featured_data.csv')
#all_csv = malicious_csv.append(benign_csv, ignore_index = True)
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_23508\3689947672.py:4: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_csv = pd.read_csv('../test_data/featured_data.csv')

# %%
code, uniques = all_csv['tld'].factorize()
all_csv['tld'] = code

code, uniques = all_csv['type'].factorize()
all_csv['type'] = code
all_csv.head()
# Out:
#    type  use_of_ip  abnormal_url  google_index  count.  count-www  count@  \
# 0     0          0             0             1       2          0       0
# 1     1          0             0             1       2          0       0
# 2     1          0             0             1       2          0       0
# 3     2          0             1             1       3          1       0
# 4     2          0             1             1       2          0       0
#
#    count_dir  count_embed_domian  short_url  ...  count-  count=  url_length  \
# 0          0                   0          0  ...       1       0          16
# 1          2                   0          0  ...       0       0          35
# 2          3                   0          0  ...       0       0          31
# 3          1                   0          0  ...       1       4          88
# 4          1                   0          0  ...       1       3         235
#
#    hostname_length  sus_url  count-digits  count-letters  fd_length  tld  \
# 0                0        0             0             13          0   -1
# 1                0        0             1             29          5   -1
# 2                0        0             1             25          7   -1
# 3               21        0             7             63          9    0
# 4               23        0            22            199          9    1
#
#    tld_length
# 0          -1
# 1          -1
# 2          -1
# 3           2
# 4           3
#
# [5 rows x 24 columns]

# %%
all_csv.tail()
# Out:
#         type  use_of_ip  abnormal_url  google_index  count.  count-www  \
# 640189     0          0             0             1       3          0
# 640190     0          0             0             1       2          0
# 640191     0          0             0             1       2          1
# 640192     0          0             0             1       2          0
# 640193     0          0             0             1       2          1
#
#         count@  count_dir  count_embed_domian  short_url  ...  count-  count=  \
# 640189       0          3                   0          0  ...       0       0
# 640190       0          4                   0          1  ...       2       0
# 640191       0          4                   0          1  ...       0       0
# 640192       0          2                   0          0  ...       0       0
# 640193       0          3                   0          0  ...       0       0
#
#         url_length  hostname_length  sus_url  count-digits  count-letters  \
# 640189          39                0        0            12             21
# 640190          44                0        0             7             29
# 640191          42                0        0             3             33
# 640192          45                0        0             0             36
# 640193          41                0        0             0             36
#
#         fd_length  tld  tld_length
# 640189          7   -1          -1
# 640190          8   -1          -1
# 640191          7   -1          -1
# 640192          4   -1          -1
# 640193          4   -1          -1
#
# [5 rows x 24 columns]

# %%
#Converting to csv
filepath = Path('../test_data/ready_for_training.csv')
all_csv.to_csv(filepath, index=False)
