# %%
import pandas as pd
from pathlib import Path

# %%
#Read csv
all_csv = pd.read_csv('../test_data/featured_data.csv')
print(all_csv)
# Out:
#               type  use_of_ip  abnormal_url  google_index  count.  count-www  \
# 0         phishing          0             0             1       2          0
# 1           benign          0             0             1       2          0
# 2           benign          0             0             1       2          0
# 3       defacement          0             0             1       3          1
# 4       defacement          0             0             1       2          0
# ...            ...        ...           ...           ...     ...        ...
# 799993      benign          0             0             1       2          1
# 799994      benign          0             0             1       3          1
# 799995      benign          0             0             1       2          1
# 799996      benign          0             0             1       3          1
# 799997      benign          0             0             1       3          1
#
#         count@  count_dir  count_embed_domian  short_url  ...  count-  count=  \
# 0            0          0                   0          0  ...       1       0
# 1            0          2                   0          0  ...       0       0
# 2            0          3                   0          0  ...       0       0
# 3            0          1                   0          0  ...       1       4
# 4            0          1                   0          0  ...       1       3
# ...        ...        ...                 ...        ...  ...     ...     ...
# 799993       0          1                   0          1  ...       0       0
# 799994       0          1                   0          0  ...       0       0
# 799995       0          1                   0          0  ...       0       0
# 799996       0          1                   0          0  ...       0       0
# 799997       0          1                   0          0  ...       0       0
#
#         url_length  hostname_length  sus_url  count-digits  count-letters  \
# 0               16                0        0             0             13
# 1               35                0        0             1             29
# 2               31                0        0             1             25
# 3               81                0        0             7             59
# 4              228                0        0            22            195
# ...            ...              ...      ...           ...            ...
# 799993          24                0        0             0             21
# 799994          27                0        0             0             23
# 799995          20                0        0             0             17
# 799996          29                0        0             0             25
# 799997          30                0        0             0             26
#
#         fd_length  tld  tld_length
# 0               0  NaN          -1
# 1               5  NaN          -1
# 2               7  NaN          -1
# 3               9  NaN          -1
# 4               9  NaN          -1
# ...           ...  ...         ...
# 799993          0  NaN          -1
# 799994          0  NaN          -1
# 799995          0  NaN          -1
# 799996          9  NaN          -1
# 799997         10  NaN          -1
#
# [799998 rows x 22 columns]

# %%
#Deleting url column

benign = all_csv.loc[all_csv["type"].isin(["benign"])]
benign = benign.sample(n=200000)
all_csv.drop(all_csv.index[(all_csv["type"].isin(["benign"]))],axis=0,inplace=True)
all_csv = pd.concat([all_csv, benign])

code, uniques = all_csv['tld'].factorize()
all_csv['tld'] = code

code, uniques = all_csv['type'].factorize()
all_csv['type'] = code
print(all_csv['type'].value_counts())
# Out:
# 3    200000
# 1     96457
# 0     91109
# 2     32321
# Name: type, dtype: int64

# %%
all_csv.tail()
# Out:
#         type  use_of_ip  abnormal_url  google_index  count.  count-www  \
# 366083     3          0             0             1       1          0
# 490358     3          0             0             1       2          0
# 162698     3          0             0             1       1          0
# 1352       3          0             0             1       3          0
# 41350      3          0             0             1       1          0
#
#         count@  count_dir  count_embed_domian  short_url  ...  count-  count=  \
# 366083       0          1                   0          0  ...       0       1
# 490358       0          1                   0          0  ...       3       0
# 162698       0          3                   0          0  ...       0       0
# 1352         0          4                   0          1  ...       0       0
# 41350        0          1                   0          0  ...       0       0
#
#         url_length  hostname_length  sus_url  count-digits  count-letters  \
# 366083          31                0        0             1             26
# 490358          57                0        0             4             43
# 162698          32                0        0             7             21
# 1352            62                0        0             1             52
# 41350           28                0        0             0             26
#
#         fd_length  tld  tld_length
# 366083          5   -1          -1
# 490358         41   -1          -1
# 162698          5   -1          -1
# 1352            2   -1          -1
# 41350          16   -1          -1
#
# [5 rows x 22 columns]

# %%
#Converting to csv
filepath = Path('../test_data/ready_for_training.csv')
all_csv.to_csv(filepath, index=False)
